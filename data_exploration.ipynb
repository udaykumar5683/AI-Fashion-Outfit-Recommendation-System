# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
products = pd.read_csv(r"E:\Fashion\ML-TASK-main\ML-TASK-main\products.csv")
outfits = pd.read_csv(r"E:\Fashion\ML-TASK-main\ML-TASK-main\outfits.csv")

print("Products Shape:", products.shape)
print("Outfits Shape:", outfits.shape)
# Out:
# Products Shape: (68, 18)
# Outfits Shape: (25, 22)

# %%
products.head()
# Out:
#                 id                                      name         brand  \
# 0  myntra_28569210              Cotton Slim Fit Formal Shirt         Arrow
# 1   ajio_469618352          Men Regular Fit 2-Piece Suit Set         ARROW
# 2   ajio_443087217    Men Oversized Fit Crew-Neck Sweatshirt          DNMX
# 3   ajio_464835118  Track Pants with Elasticated Drawstrings  Jack & Jones
# 4   ajio_703306501               Men Regular Fit Linen Shirt      NEONOMAD
#
#    price_inr  rating  rating_count gender wear_type       category  \
# 0       1099     4.5          69.0    men   western  formal-shirts
# 1       5000     3.3           NaN    men   western          suits
# 2        300     4.0           NaN    men   western    sweatshirts
# 3        602     3.8           NaN    men   western    track-pants
# 4        960     NaN           NaN    men   western   linen-shirts
#
#   category_label  occasion                                         tags  \
# ...

# %%
outfits.head()
# Out:
#    outfit_id gender wear_type occasion                    theme  \
# 0  outfit W1  women   western    party           Black cocktail
# 1  outfit W2  women   western    party     Wine bodycon evening
# 2  outfit W3  women   western    party  Magenta slip, night out
# 3  outfit W4  women    ethnic  festive      Dusty-blue Anarkali
# 4  outfit W5  women    ethnic  wedding       Red Banarasi saree
#
#                                                 hero          hero_id second  \
# 0        Women Bodycon Midi Length Dress (Fyre Rose)   ajio_703182002    NaN
# 1                       Bodycon Midi Dress (MULVARI)  myntra_41733768    NaN
# 2             Ruched Asymmetrical Midi Dress (MANGO)  myntra_34682942    NaN
# 3  Women Embellished Anarkali Kurta Suit Set (SVA...   ajio_702454568    NaN
# 4  Women Floral Woven Banarasi Silk Saree (Stylee...   ajio_467147176    NaN
#
#   second_id layer  ...      footwear_id  \
# 0       NaN   NaN  ...  myntra_42540276
# ...

# %%
print(products.columns.tolist())
# Out:
# ['id', 'name', 'brand', 'price_inr', 'rating', 'rating_count', 'gender', 'wear_type', 'category', 'category_label', 'occasion', 'tags', 'description', 'description_source', 'image', 'site', 'product_url', 'collected_at']

# %%
print(outfits.columns.tolist())
# Out:
# ['outfit_id', 'gender', 'wear_type', 'occasion', 'theme', 'hero', 'hero_id', 'second', 'second_id', 'layer', 'layer_id', 'footwear', 'footwear_id', 'accessory_1', 'accessory_1_id', 'accessory_2', 'accessory_2_id', 'palette', 'items_count', 'total_price_inr', 'image_files', 'stylist_rationale']

# %%
products.isnull().sum()
# Out:
# id                     0
# name                   0
# brand                  0
# price_inr              0
# rating                25
# rating_count          42
# gender                 0
# wear_type              0
# category               0
# category_label         0
# occasion               0
# tags                   0
# description            0
# description_source     0
# image                  0
# site                   0
# product_url            0
# collected_at           0
# dtype: int64

# %%
outfits.isnull().sum()
# Out:
# outfit_id             0
# gender                0
# wear_type             0
# occasion              0
# theme                 0
# hero                  0
# hero_id               0
# second               12
# second_id            12
# layer                21
# layer_id             21
# footwear              0
# footwear_id           0
# accessory_1           3
# accessory_1_id        3
# accessory_2          21
# accessory_2_id       21
# palette               0
# items_count           0
# total_price_inr       0
# image_files           0
# stylist_rationale     0
# dtype: int64

# %%
products["gender"].value_counts()
# Out:
# gender
# women    41
# men      27
# Name: count, dtype: int64

# %%
products["gender"].value_counts().plot(
    kind="bar",
    figsize=(6,4)
)

plt.title("Gender Distribution")
plt.show()

# %%
products["occasion"].value_counts()
# Out:
# occasion
# casual      15
# party       13
# office      12
# festive      9
# wedding      6
# sports       5
# vacation     4
# winter       4
# Name: count, dtype: int64

# %%
products["occasion"].value_counts().plot(
    kind="bar",
    figsize=(8,4)
)

plt.title("Occasion Distribution")
plt.show()

# %%
products["category_label"].value_counts().head(15)
# Out:
# category_label
# Ethnic Footwear    4
# Clutches           4
# Heels              4
# Party Dresses      3
# Formal Shirts      3
# Necklaces          2
# Kurta Sets         2
# Trousers           2
# Handbags           2
# Watches            2
# Boots              2
# Jeans              2
# Formal Shoes       2
# Sweatshirts        1
# Track Pants        1
# Name: count, dtype: int64

# %%
products["category_label"].value_counts().head(15).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top Categories")
plt.show()

# %%
products["brand"].value_counts().head(15)
# Out:
# brand
# MANGO                         2
# TITAN                         2
# SVARAA                        2
# Lavie                         2
# NEONOMAD                      1
# Arrow                         1
# DNMX                          1
# ARROW                         1
# Nyrika                        1
# Puma                          1
# Forever Glam by Pantaloons    1
# DFR                           1
# VATSALYA                      1
# KISAH                         1
# Fyre Rose                     1
# Name: count, dtype: int64

# %%
outfits.head()
# Out:
#    outfit_id gender wear_type occasion                    theme  \
# 0  outfit W1  women   western    party           Black cocktail
# 1  outfit W2  women   western    party     Wine bodycon evening
# 2  outfit W3  women   western    party  Magenta slip, night out
# 3  outfit W4  women    ethnic  festive      Dusty-blue Anarkali
# 4  outfit W5  women    ethnic  wedding       Red Banarasi saree
#
#                                                 hero          hero_id second  \
# 0        Women Bodycon Midi Length Dress (Fyre Rose)   ajio_703182002    NaN
# 1                       Bodycon Midi Dress (MULVARI)  myntra_41733768    NaN
# 2             Ruched Asymmetrical Midi Dress (MANGO)  myntra_34682942    NaN
# 3  Women Embellished Anarkali Kurta Suit Set (SVA...   ajio_702454568    NaN
# 4  Women Floral Woven Banarasi Silk Saree (Stylee...   ajio_467147176    NaN
#
#   second_id layer  ...      footwear_id  \
# 0       NaN   NaN  ...  myntra_42540276
# ...

# %%
sample = outfits.iloc[0]

print("Outfit ID:", sample["outfit_id"])
print("Theme:", sample["theme"])

print("\nHero:", sample["hero"])
print("Second:", sample["second"])
print("Layer:", sample["layer"])
print("Footwear:", sample["footwear"])

print("\nStylist Reason:")
print(sample["stylist_rationale"])
# Out:
# Outfit ID: outfit W1
# Theme: Black cocktail
#
# Hero: Women Bodycon Midi Length Dress (Fyre Rose)
# Second: nan
# Layer: nan
# Footwear: Classic Women's Heels (Lavie)
#
# Stylist Reason:
# Black midi with a gold chain waist detail; gold crystal slingback pumps echo that hardware, and a soft blush box clutch keeps the eye on the dress.

# %%
print(products.columns.tolist())
# Out:
# ['id', 'name', 'brand', 'price_inr', 'rating', 'rating_count', 'gender', 'wear_type', 'category', 'category_label', 'occasion', 'tags', 'description', 'description_source', 'image', 'site', 'product_url', 'collected_at']

# %%
print(outfits.columns.tolist())
# Out:
# ['outfit_id', 'gender', 'wear_type', 'occasion', 'theme', 'hero', 'hero_id', 'second', 'second_id', 'layer', 'layer_id', 'footwear', 'footwear_id', 'accessory_1', 'accessory_1_id', 'accessory_2', 'accessory_2_id', 'palette', 'items_count', 'total_price_inr', 'image_files', 'stylist_rationale']
